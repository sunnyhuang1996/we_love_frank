# %%
import arff
import numpy as np

from sklearn.decomposition import PCA

train = arff.load(open('train.arff', 'rb'))
test = arff.load(open('test.arff', 'rb'))

train = train['data']
test = test['data']

train_num = len(train)
test_num = len(test)
traindata=np.zeros((train_num, 20))
trainlabel = np.zeros(train_num)
testdata = np.zeros((len(test), 20))
testlabel = np.zeros(test_num)

for d in range(0, train_num):
    data = train[d]
    traindata[:d] = np.asarray(data[:-1])
    trainlabel[d] = data[-1]
    
for d in range(0, test_num):
    data = test[d]
    testdata[:d] = np.asarray(data[:-1])
    testlabel[d] = data[-1]

total = np.vstack((traindata, testdata))
pca = PCA(n_components=2).fit_transform(total)
traindata = pca[:train_num]
testdata = pca[:test_num]         

clf = svm.SVC(kernel='linear', probability=True)
clf.fit(traindata, trainlabel)
print clf.score(testdata, testlabel)
# Out:
# 0.506963788301

# %%
from util import *
import sys


def InitNN(num_inputs, num_hiddens, num_outputs):
    """Initializes NN parameters."""
    W1 = 0.01 * np.random.randn(num_inputs, num_hiddens)
    W2 = 0.01 * np.random.randn(num_hiddens, num_outputs)
    b1 = np.zeros((num_hiddens, 1))
    b2 = np.zeros((num_outputs, 1))
    return W1, W2, b1, b2

def TrainNN(num_hiddens, eps, momentum, num_epochs):
    
    
    """Trains a single hidden layer NN.
    
    Inputs:
    num_hiddens: NUmber of hidden units.
    eps: Learning rate.
    momentum: Momentum.
    num_epochs: Number of epochs to run training for.

    Returns:
    W1: First layer weights.
    W2: Second layer weights.
    b1: Hidden layer bias.
    b2: Output layer bias.
    train_error: Training error at at epoch.
    valid_error: Validation error at at epoch.
    """
        
    #read data
    train = arff.load(open('train.arff', 'rb'))
    test = arff.load(open('test.arff', 'rb'))

    train = train['data']
    test = test['data']

    train_num = len(train)
    test_num = len(test)
    traindata=np.zeros((train_num, 20))
    trainlabel = np.zeros(train_num)
    testdata = np.zeros((len(test), 20))
    testlabel = np.zeros(test_num)

    for d in range(0, train_num):
        data = train[d]
        traindata[:d] = np.asarray(data[:-1])
        trainlabel[d] = data[-1]

    for d in range(0, test_num):
        data = test[d]
        testdata[:d] = np.asarray(data[:-1])
        testlabel[d] = data[-1]
    
    inputs_train = traindata.T
    target_train = (trainlabel.reshape(1,trainlabel.shape[0]))/4.0
    inputs_test = testdata.T
    target_test = (testlabel.reshape(1,testlabel.shape[0]))/4.0
    
    print inputs_train.shape, target_train.shape, inputs_test.shape, target_test.shape
    
    W1, W2, b1, b2 = InitNN(inputs_train.shape[0], num_hiddens, target_train.shape[0])
    dW1 = np.zeros(W1.shape)
    dW2 = np.zeros(W2.shape)
    db1 = np.zeros(b1.shape)
    db2 = np.zeros(b2.shape)
    train_error = []
    valid_error = []
    num_train_cases = inputs_train.shape[1]
    for epoch in xrange(num_epochs):
        # Forward prop
        h_input = np.dot(W1.T, inputs_train) + b1  # Input to hidden layer.
        h_output = 1 / (1 + np.exp(-h_input))  # Output of hidden layer.
        logit = np.dot(W2.T, h_output) + b2  # Input to output layer.
        prediction = 1 / (1 + np.exp(-logit))  # Output prediction.  #probability if >0.5 correct
        
        print prediction.shape
        # Compute cross entropy
        train_CE = -np.mean(target_train * np.log(prediction) + (1 - target_train) * np.log(1 - prediction))
        print train_CE
        # Compute deriv
        dEbydlogit = prediction - target_train

        # Backprop
        dEbydh_output = np.dot(W2, dEbydlogit)
        dEbydh_input = dEbydh_output * h_output * (1 - h_output)

        # Gradients for weights and biases.
        dEbydW2 = np.dot(h_output, dEbydlogit.T)
        dEbydb2 = np.sum(dEbydlogit, axis=1).reshape(-1, 1)
        dEbydW1 = np.dot(inputs_train, dEbydh_input.T)
        dEbydb1 = np.sum(dEbydh_input, axis=1).reshape(-1, 1)

        #%%%% Update the weights at the end of the epoch %%%%%%
        dW1 = momentum * dW1 - (eps / num_train_cases) * dEbydW1
        dW2 = momentum * dW2 - (eps / num_train_cases) * dEbydW2
        db1 = momentum * db1 - (eps / num_train_cases) * dEbydb1
        db2 = momentum * db2 - (eps / num_train_cases) * dEbydb2

        W1 = W1 + dW1
        W2 = W2 + dW2
        b1 = b1 + db1
        b2 = b2 + db2

        valid_CE = Evaluate(inputs_test, target_test, W1, W2, b1, b2)

        train_error.append(train_CE)
        valid_error.append(valid_CE)
        sys.stdout.write('\rStep %d Train CE %.5f Validation CE %.5f' % (epoch, train_CE, valid_CE))
        sys.stdout.flush()
        if (epoch % 100 == 0):
            sys.stdout.write('\n')

    sys.stdout.write('\n')
    final_train_error = Evaluate(inputs_train, target_train, W1, W2, b1, b2)
    #final_valid_error = Evaluate(inputs_valid, target_valid, W1, W2, b1, b2)
    #final_test_error = Evaluate(inputs_test, target_test, W1, W2, b1, b2)
    #print 'Error: Train %.5f Validation %.5f Test %.5f' % (final_train_error, final_valid_error, final_test_error)
    return W1, W2, b1, b2, train_error, valid_error
  

def Evaluate(inputs, target, W1, W2, b1, b2):
    """Evaluates the model on inputs and target."""
    h_input = np.dot(W1.T, inputs) + b1  # Input to hidden layer.
    h_output = 1 / (1 + np.exp(-h_input))  # Output of hidden layer.
    logit = np.dot(W2.T, h_output) + b2  # Input to output layer.
    prediction = 1 / (1 + np.exp(-logit))  # Output prediction.
    #CE = -np.mean(target * np.log(prediction) + (1 - target) * np.log(1 - prediction))
    CE = np.mean(np.round(abs(target-prediction), 0)) #correct rate
    return CE


def main():
    num_hiddens = 50
    eps = 0.02
    momentum = 0.5
    num_epochs = 2000
    W1, W2, b1, b2, train_error, valid_error = TrainNN(num_hiddens, eps, momentum, num_epochs)
    DisplayErrorPlot(train_error, valid_error) 
    # If you wish to save the model for future use :
    # outputfile = 'model.npz'
    # SaveModel(outputfile, W1, W2, b1, b2, train_error, valid_error)

if __name__ == '__main__':
    main()
# Out:
# (20, 11000) (1, 11000) (20, 359) (1, 359)
# (1, 11000)
# 0.61095078625
# Step 0 Train CE 0.61095 Validation CE 0.02973
# (1, 11000)
# 0.0374566842881
# Step 1 Train CE 0.03746 Validation CE -0.75484(1, 11000)
# -0.727707185239
# Step 2 Train CE -0.72771 Validation CE -1.57872(1, 11000)
# -1.51468012986
# Step 3 Train CE -1.51468 Validation CE -2.41544(1, 11000)
# -2.28753783266
# Step 4 Train CE -2.28754 Validation CE -3.29223(1, 11000)
# -3.0643046004
# Step 5 Train CE -3.06430 Validation CE -4.24906(1, 11000)
# -3.8766328905
# Step 6 Train CE -3.87663 Validation CE -5.32287(1, 11000)
# -4.75625228005
# Step 7 Train CE -4.75625 Validation CE -6.54045(1, 11000)
# -5.73100217836
# Step 8 Train CE -5.73100 Validation CE -7.91369(1, 11000)
# -6.82295958719
# Step 9 Train CE -6.82296 Validation CE -9.43731(1, 11000)
# -8.04673271496
# Step 10 Train CE -8.04673 Validation CE -11.09054(1, 11000)
# -9.40801887583
# Step 11 Train CE -9.40802 Validation CE -12.84314(1, 11000)
# -10.9031157862
# Step 12 Train CE -10.90312 Validation CE -14.66360(1, 11000)
# -12.5199590638
# Step 13 Train CE -12.51996 Validation CE -16.52613(1, 11000)
# -14.2406747438
# Step 14 Train CE -14.24067 Validation CE -18.41375(1, 11000)
# -16.0449340696
# Step 15 Train CE -16.04493 Validation CE -20.31763(1, 11000)
# -17.9130627968
# Step 16 Train CE -17.91306 Validation CE -22.23443(1, 11000)
# -19.8281145881
# Step 17 Train CE -19.82811 Validation CE -24.16350(1, 11000)
# -21.7767124559
# Step 18 Train CE -21.77671 Validation CE -26.10505(1, 11000)
# -23.7489461344
# Step 19 Train CE -23.74895 Validation CE -28.05915(1, 11000)
# -25.7377915448
# Step 20 Train CE -25.73779 Validation CE -30.02549(1, 11000)
# -27.7384971165
# Step 21 Train CE -27.73850 Validation CE -32.00293(1, 11000)
# -29.7482196257
# Step 22 Train CE -29.74822 Validation CE -34.00365(1, 11000)
# -31.7608343129
# Step 23 Train CE -31.76083 Validation CE -36.19387(1, 11000)
# -33.7491640989
# Step 24 Train CE -33.74916 Validation CE nan(1, 11000)
# -36.0522353459
# Step 25 Train CE -36.05224 Validation CE nan(1, 11000)
# nan
# Step 26 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 27 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 28 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 29 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 30 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 31 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 32 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 33 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 34 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 35 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 36 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 37 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 38 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 39 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 40 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 41 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 42 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 43 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 44 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 45 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 46 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 47 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 48 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 49 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 50 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 51 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 52 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 53 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 54 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 55 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 56 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 57 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 58 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 59 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 60 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 61 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 62 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 63 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 64 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 65 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 66 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 67 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 68 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 69 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 70 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 71 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 72 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 73 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 74 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 75 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 76 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 77 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 78 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 79 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 80 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 81 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 82 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 83 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 84 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 85 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 86 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 87 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 88 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 89 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 90 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 91 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 92 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 93 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 94 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 95 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 96 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 97 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 98 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 99 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 100 Train CE nan Validation CE nan
# (1, 11000)
# nan
# Step 101 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 102 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 103 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 104 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 105 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 106 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 107 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 108 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 109 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 110 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 111 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 112 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 113 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 114 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 115 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 116 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 117 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 118 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 119 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 120 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 121 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 122 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 123 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 124 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 125 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 126 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 127 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 128 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 129 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 130 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 131 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 132 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 133 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 134 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 135 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 136 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 137 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 138 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 139 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 140 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 141 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 142 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 143 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 144 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 145 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 146 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 147 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 148 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 149 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 150 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 151 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 152 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 153 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 154 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 155 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 156 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 157 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 158 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 159 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 160 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 161 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 162 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 163 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 164 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 165 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 166 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 167 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 168 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 169 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 170 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 171 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 172 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 173 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 174 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 175 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 176 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 177 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 178 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 179 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 180 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 181 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 182 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 183 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 184 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 185 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 186 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 187 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 188 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 189 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 190 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 191 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 192 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 193 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 194 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 195 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 196 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 197 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 198 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 199 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 200 Train CE nan Validation CE nan
# (1, 11000)
# nan
# Step 201 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 202 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 203 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 204 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 205 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 206 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 207 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 208 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 209 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 210 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 211 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 212 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 213 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 214 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 215 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 216 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 217 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 218 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 219 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 220 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 221 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 222 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 223 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 224 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 225 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 226 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 227 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 228 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 229 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 230 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 231 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 232 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 233 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 234 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 235 Train CE nan Validation CE nan(1, 11000)
# nan
# Step 236 Train CE nan Validation CE nan
# /Users/fang/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:130: RuntimeWarning: divide by zero encountered in log
# /Users/fang/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:81: RuntimeWarning: divide by zero encountered in log
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-7790553d683e> in <module>()
#     145
#     146 if __name__ == '__main__':
# --> 147     main()
#
# <ipython-input-55-7790553d683e> in main()
#     138     momentum = 0.5
#     139     num_epochs = 2000
# --> 140     W1, W2, b1, b2, train_error, valid_error = TrainNN(num_hiddens, eps, momentum, num_epochs)
#     141     DisplayErrorPlot(train_error, valid_error)
#     142     # If you wish to save the model for future use :
#
# <ipython-input-55-7790553d683e> in TrainNN(num_hiddens, eps, momentum, num_epochs)
#      72     for epoch in xrange(num_epochs):
#      73         # Forward prop
# ---> 74         h_input = np.dot(W1.T, inputs_train) + b1  # Input to hidden layer.
#      75         h_output = 1 / (1 + np.exp(-h_input))  # Output of hidden layer.
#      76         logit = np.dot(W2.T, h_output) + b2  # Input to output layer.
#
# KeyboardInterrupt:
